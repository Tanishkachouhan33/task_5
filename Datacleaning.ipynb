# %%
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df2=pd.read_csv("/content/LED.csv")

# %%
df2.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1       c###bd  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
df2.duplicated().sum()
# Out:
# np.int64(6)

# %%
df2.drop_duplicates(inplace=True)

# %%
df2.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness 1-19 years                 34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df2.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
# BMI                                float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# GDP                                float64
# Population                         float64
# thinness 1-19 years                float64
# thinness 5-9 years                 float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
df2["Population"]=df2["Population"].fillna(df2["Population"].mean())

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer()
df2[['GDP']] = imputer.fit_transform(df2[['GDP']])

# %%
df2.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
# BMI                                0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
# HIV/AIDS                           0
# GDP                                0
# Population                         0
# thinness 1-19 years                0
# thinness 5-9 years                 0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
colu=df2.select_dtypes(include="number").columns
for i in colu:
  if df2[i].isnull().sum() != 0:
    df2[i]=df2[i].fillna(df2[i].mean())

# %%
df2.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
# BMI                                0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
# HIV/AIDS                           0
# GDP                                0
# Population                         0
# thinness 1-19 years                0
# thinness 5-9 years                 0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
df2.shape
# Out:
# (2938, 22)

# %%
file.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3477293748.py in <cell line: 0>()
# ----> 1 file.isnull().sum()
#
# NameError: name 'file' is not defined

# %% [markdown]
# #perform EDA

# %%
df2.describe()
# Out:
#               Year  Life expectancy  Adult Mortality  infant deaths  \
# count  2938.000000      2938.000000      2938.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.507640       124.080302     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.200000        74.000000       0.000000
# 50%    2008.000000        72.000000       144.000000       3.000000
# 75%    2012.000000        75.600000       227.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B        Measles  \
# count  2938.000000             2938.000000  2938.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       3.916288             1987.914858    22.586855   11467.272489
# ...

# %%
df2.describe().T
# Out:
#                                   count          mean           std  \
# Year                             2938.0  2.007519e+03  4.613841e+00
# Life expectancy                  2938.0  6.922493e+01  9.507640e+00
# Adult Mortality                  2938.0  1.647964e+02  1.240803e+02
# infant deaths                    2938.0  3.030395e+01  1.179265e+02
# Alcohol                          2938.0  4.602861e+00  3.916288e+00
# percentage expenditure           2938.0  7.382513e+02  1.987915e+03
# Hepatitis B                      2938.0  8.094046e+01  2.258685e+01
# Measles                          2938.0  2.419592e+03  1.146727e+04
# BMI                              2938.0  3.832125e+01  1.992768e+01
# under-five deaths                2938.0  4.203574e+01  1.604455e+02
# Polio                            2938.0  8.255019e+01  2.335214e+01
# Total expenditure                2938.0  5.938190e+00  2.400274e+00
# Diphtheria                       2938.0  8.232408e+01  2.364007e+01
# ...

# %%
df2.select_dtypes(include="object").describe().T
# Out:
#         count unique         top  freq
# Country  2938    195     Albania    16
# Status   2938      2  Developing  2426

# %%
for col in df2.select_dtypes(include="number").columns:
  sns.histplot(data=df2,x=col)
  plt.show()

# %%
for col in df2.select_dtypes(include="number").columns:
  sns.boxplot(data=df2,x=col)
  plt.show()

# %%
df2.select_dtypes(include="number").columns
# Out:
# Index(['Year', 'Life expectancy', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles', 'BMI',
#        'under-five deaths', 'Polio', 'Total expenditure', 'Diphtheria',
#        'HIV/AIDS', 'GDP', 'Population', 'thinness 1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
s=[
    'Year', 'Adult Mortality', 'infant deaths',
    'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles', 'BMI',
    'under-five deaths', 'Polio', 'Total expenditure', 'Diphtheria',
    'HIV/AIDS', 'GDP', 'Population', 'thinness 1-19 years',
    'thinness 5-9 years', 'Income composition of resources', 'Schooling'
]

# %%
cr=df2.select_dtypes(include="number").corr()

# %%
plt.figure(figsize=(18,18))
sns.heatmap(cr,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer()
df[['GDP']] = imputer.fit_transform(df[['GDP']])
